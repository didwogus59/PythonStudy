# %%
import sklearn
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('LinearRegressionData.csv')

# %%
dataset.head()
# Out:
#    hour  score
# 0   0.5     10
# 1   1.2      8
# 2   1.8     14
# 3   2.4     26
# 4   2.6     22

# %%
X = dataset.iloc[:,:-1].values
y = dataset.iloc[:, -1].values

# %%
X
# Out:
# array([[ 0.5],
#        [ 1.2],
#        [ 1.8],
#        [ 2.4],
#        [ 2.6],
#        [ 3.2],
#        [ 3.9],
#        [ 4.4],
#        [ 4.5],
#        [ 5. ],
#        [ 5.3],
#        [ 5.8],
#        [ 6. ],
#        [ 6.1],
#        [ 6.2],
#        [ 6.9],
#        [ 7.2],
#        [ 8.4],
#        [ 8.6],
#        [10. ]])

# %%
y
# Out:
# array([ 10,   8,  14,  26,  22,  30,  42,  48,  38,  58,  60,  72,  62,
#         68,  72,  58,  76,  86,  90, 100])

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()

reg.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X)
y_pred
# Out:
# array([  5.00336377,  12.31395163,  18.58016979,  24.84638795,
#         26.93512734,  33.20134551,  40.51193337,  45.73378184,
#         46.77815153,  52.        ,  55.13310908,  60.35495755,
#         62.44369694,  63.48806663,  64.53243633,  71.84302419,
#         74.97613327,  87.5085696 ,  89.59730899, 104.2184847 ])

# %%
plt.scatter(X, y, color = "blue")
plt.plot(X, y_pred, color = "green")
plt.title("Score bt Hours")
plt.ylabel("Score")
plt.xlabel("Hours")
# Out:
# Text(0.5, 0, 'Hours')

# %%
print('9, 8 Hour Score : ', reg.predict([[9], [8]]) )
# Out:
# 9, 8 Hour Score :  [93.77478776 83.33109082]

# %%
reg.coef_
# Out:
# array([10.44369694])

# %%
reg.intercept_
# Out:
# np.float64(-0.218484702867201)

# %%
# y = mx + b
# y = 10.4436 x + (-0.2184)

# %%
### Split Data Set

# %%
import sklearn
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('LinearRegressionData.csv')

# %%
X = dataset.iloc[:, :-1].values

# %%
y = dataset.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=0)

# %%
X, len(x)
# Out:
# (array([[ 0.5],
#         [ 1.2],
#         [ 1.8],
#         [ 2.4],
#         [ 2.6],
#         [ 3.2],
#         [ 3.9],
#         [ 4.4],
#         [ 4.5],
#         [ 5. ],
#         [ 5.3],
#         [ 5.8],
#         [ 6. ],
#         [ 6.1],
#         [ 6.2],
#         [ 6.9],
#         [ 7.2],
#         [ 8.4],
#         [ 8.6],
#         [10. ]]),
#  20)

# %%
X_train, len(X_train)
# Out:
# (array([[ 6.9],
#         [ 5. ],
#         [ 5.3],
#         [ 3.9],
#         [ 6.2],
#         [ 1.2],
#         [ 5.8],
#         [ 8.6],
#         [ 4.4],
#         [ 2.4],
#         [ 4.5],
#         [ 0.5],
#         [ 1.8],
#         [ 3.2],
#         [ 6.1],
#         [10. ]]),
#  16)

# %%
X_test, len(X_test)
# Out:
# (array([[2.6],
#         [6. ],
#         [7.2],
#         [8.4]]),
#  4)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()

# %%
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)

# %%
plt.scatter(X_test, y_test, color = "blue")
plt.plot(X_train, reg.predict(X_train), color = "green")
plt.title("Score bt Hours")
plt.ylabel("Score")
plt.xlabel("Hours")
# Out:
# Text(0.5, 0, 'Hours')

# %%
reg.score(X_test, y_test)
# Out:
# 0.9858550623163561

# %%
reg.score(X_train, y_train)
# Out:
# 0.9442767399506566

# %%
from sklearn.linear_model import SGDRegressor

sr = SGDRegressor(max_iter=1000, eta0=0.001, random_state=0,verbose=1)
sr.fit(X_train, y_train)
# Out:
# -- Epoch 1
# Norm: 2.58, NNZs: 1, Bias: 0.427456, T: 16, Avg. loss: 1222.713399, Objective: 1222.713523
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm:
# Total training time: 0.00 seconds.
# -- Epoch 30
# Norm: 10.00, NNZs: 1, Bias: 1.622153, T: 480, Avg. loss: 20.779833, Objective: 20.784818
# Total training time: 0.00 seconds.
# -- Epoch 31
# Norm: 10.02, NNZs: 1, Bias: 1.623969, T: 496, Avg. loss: 20.682916, Objective: 20.687934
# Total training time: 0.00 seconds.
# -- Epoch 32
# Norm: 10.03, NNZs: 1, Bias: 1.625528, T: 512, Avg. loss: 20.607535, Objective: 20.612573
# Total training time: 0.00 seconds.
# -- Epoch 33
# Norm: 10.05, NNZs: 1, Bias: 1.627151, T: 528, Avg. loss: 20.539552, Objective: 20.544580
# Total training time: 0.00 seconds.
# -- Epoch 34
# Norm: 10.06, NNZs: 1, Bias: 1.628498, T: 544, Avg. loss: 20.484060, Objective: 20.489106
# Total training time: 0.00 seconds.
# -- Epoch 35
# Norm: 10.07, NNZs: 1, Bias: 1.629452, T: 560, Avg. loss: 20.443047, Objective: 20.448116
# Total training time: 0.00 seconds.
# -- Epoch 36
# Norm: 10.08, NNZs: 1, Bias: 1.630252, T: 576, Avg. loss: 20.407726, Objective: 20.412806
# Total training time: 0.00 seconds.
# -- Epoch 37
# Norm: 10.09, NNZs: 1, Bias: 1.631008, T: 592, Avg. loss: 20.379014, Objective: 20.384095
# Total training time: 0.00 seconds.
# -- Epoch 38
# Norm: 10.10, NNZs: 1, Bias: 1.631593, T: 608, Avg. loss: 20.355517, Objective: 20.360609
# Total training time: 0.00 seconds.
# -- Epoch 39
# Norm: 10.11, NNZs: 1, Bias: 1.632061, T: 624, Avg. loss: 20.335027, Objective: 20.340126
# Total training time: 0.00 seconds.
# -- Epoch 40
# Norm: 10.11, NNZs: 1, Bias: 1.632171, T: 640, Avg. loss: 20.317284, Objective: 20.322406
# Total training time: 0.00 seconds.
# -- Epoch 41
# Norm: 10.12, NNZs: 1, Bias: 1.632443, T: 656, Avg. loss: 20.307305, Objective: 20.312418
# Total training time: 0.00 seconds.
# -- Epoch 42
# Norm: 10.13, NNZs: 1, Bias: 1.632596, T: 672, Avg. loss: 20.295951, Objective: 20.301072
# Total training time: 0.00 seconds.
# -- Epoch 43
# Norm: 10.13, NNZs: 1, Bias: 1.632699, T: 688, Avg. loss: 20.285019, Objective: 20.290141
# Total training time: 0.00 seconds.
# -- Epoch 44
# Norm: 10.14, NNZs: 1, Bias: 1.632559, T: 704, Avg. loss: 20.278066, Objective: 20.283205
# Total training time: 0.00 seconds.
# -- Epoch 45
# Norm: 10.14, NNZs: 1, Bias: 1.632621, T: 720, Avg. loss: 20.269984, Objective: 20.275109
# Total training time: 0.00 seconds.
# -- Epoch 46
# Norm: 10.14, NNZs: 1, Bias: 1.632423, T: 736, Avg. loss: 20.265688, Objective: 20.270834
# Total training time: 0.00 seconds.
# -- Epoch 47
# Norm: 10.15, NNZs: 1, Bias: 1.632213, T: 752, Avg. loss: 20.261191, Objective: 20.266336
# Total training time: 0.00 seconds.
# -- Epoch 48
# Norm: 10.15, NNZs: 1, Bias: 1.631970, T: 768, Avg. loss: 20.257224, Objective: 20.262372
# Total training time: 0.00 seconds.
# -- Epoch 49
# Norm: 10.15, NNZs: 1, Bias: 1.631717, T: 784, Avg. loss: 20.252918, Objective: 20.258066
# Total training time: 0.00 seconds.
# -- Epoch 50
# Norm: 10.16, NNZs: 1, Bias: 1.631364, T: 800, Avg. loss: 20.249126, Objective: 20.254286
# Total training time: 0.00 seconds.
# -- Epoch 51
# Norm: 10.16, NNZs: 1, Bias: 1.630982, T: 816, Avg. loss: 20.247722, Objective: 20.252880
# Total training time: 0.00 seconds.
# -- Epoch 52
# Norm: 10.16, NNZs: 1, Bias: 1.630599, T: 832, Avg. loss: 20.245519, Objective: 20.250677
# Total training time: 0.00 seconds.
# -- Epoch 53
# Norm: 10.16, NNZs: 1, Bias: 1.630298, T: 848, Avg. loss: 20.241182, Objective: 20.246335
# Total training time: 0.00 seconds.
# -- Epoch 54
# Norm: 10.17, NNZs: 1, Bias: 1.629914, T: 864, Avg. loss: 20.238712, Objective: 20.243873
# Total training time: 0.00 seconds.
# -- Epoch 55
# Norm: 10.17, NNZs: 1, Bias: 1.629349, T: 880, Avg. loss: 20.239509, Objective: 20.244681
# Total training time: 0.00 seconds.
# -- Epoch 56
# Norm: 10.17, NNZs: 1, Bias: 1.628815, T: 896, Avg. loss: 20.239014, Objective: 20.244184
# Total training time: 0.00 seconds.
# -- Epoch 57
# Norm: 10.17, NNZs: 1, Bias: 1.628519, T: 912, Avg. loss: 20.231029, Objective: 20.236182
# Total training time: 0.00 seconds.
# -- Epoch 58
# Norm: 10.17, NNZs: 1, Bias: 1.627901, T: 928, Avg. loss: 20.234182, Objective: 20.239359
# Total training time: 0.00 seconds.
# -- Epoch 59
# Norm: 10.17, NNZs: 1, Bias: 1.627283, T: 944, Avg. loss: 20.234791, Objective: 20.239971
# Total training time: 0.00 seconds.
# -- Epoch 60
# Norm: 10.17, NNZs: 1, Bias: 1.626684, T: 960, Avg. loss: 20.234247, Objective: 20.239424
# Total training time: 0.00 seconds.
# -- Epoch 61
# Norm: 10.18, NNZs: 1, Bias: 1.626353, T: 976, Avg. loss: 20.225499, Objective: 20.230656
# Total training time: 0.00 seconds.
# -- Epoch 62
# Norm: 10.18, NNZs: 1, Bias: 1.625764, T: 992, Avg. loss: 20.231927, Objective: 20.237102
# Total training time: 0.00 seconds.
# -- Epoch 63
# Norm: 10.18, NNZs: 1, Bias: 1.625184, T: 1008, Avg. loss: 20.231053, Objective: 20.236229
# Total training time: 0.00 seconds.
# -- Epoch 64
# Norm: 10.18, NNZs: 1, Bias: 1.624480, T: 1024, Avg. loss: 20.229903, Objective: 20.235089
# Total training time: 0.00 seconds.
# -- Epoch 65
# Norm: 10.18, NNZs: 1, Bias: 1.624044, T: 1040, Avg. loss: 20.226166, Objective: 20.231332
# Total training time: 0.00 seconds.
# -- Epoch 66
# Norm: 10.18, NNZs: 1, Bias: 1.623541, T: 1056, Avg. loss: 20.227279, Objective: 20.232451
# Total training time: 0.00 seconds.
# Convergence after 66 epochs took 0.00 seconds
# SGDRegressor(eta0=0.001, random_state=0, verbose=1)

# %%
plt.scatter(X_train, y_train, color = "blue")
plt.plot(X_train, sr.predict(X_train), color = "green")
plt.title("Score bt Hours")
plt.ylabel("Score")
plt.xlabel("Hours")
plt.show()

# %%
sr.coef_
# Out:
# array([10.12623082])

# %%
sr.intercept_
# Out:
# array([1.68301593])

# %%
sr.score(X_train, y_train)
# Out:
# 0.9437356324545229

# %%
sr.score(X_test, y_test)
# Out:
# 0.9836085804282567
